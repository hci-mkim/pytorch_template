# %% [markdown]
# Google Drive Mount 합시다. 단축키 Ctrl+shift+M

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
# 현재 경로 확인
# !pwd
# Out:
# /content

# %%
# 현재 경로 이동(구글드라이브에서 PyTorch_Template 라는 폴더를 생성했음.)
# !cd drive/My\ Drive/
# 깃헙 코드 클론(git clone) *내가 다운로드 할 경로로 꼭 이동 후 깃 클론 해야합니다.
# !git clone https://github.com/FrancescoSaverioZuppichini/PyTorch-Deep-Learning-Template.git
# !cd PyTorch-Deep-Learning-Template
# !wget -q 'https://drive.google.com/open?id=10qsXfaCKZaLrxproT9WSUjpsks2QkM8D'
# Out:
# /content/drive/My Drive/PyTorch_Template

# %% [markdown]
# **---------------------------처음 한 번만 실행 시작---------------------------**

# %%
# 깃헙 코드 클론(git clone) *내가 다운로드 할 경로로 꼭 이동 후 깃 클론 해야합니다.
# !git clone https://github.com/FrancescoSaverioZuppichini/PyTorch-Deep-Learning-Template.git
# Out:
# Cloning into 'PyTorch-Deep-Learning-Template'...
# remote: Enumerating objects: 133, done.
# remote: Counting objects: 100% (133/133), done.
# remote: Compressing objects: 100% (121/121), done.
# remote: Total 133 (delta 53), reused 78 (delta 0), pack-reused 0
# Receiving objects: 100% (133/133), 23.14 MiB | 10.75 MiB/s, done.
# Resolving deltas: 100% (53/53), done.

# %%
# template.ipynb(지금 실행 파일)을 깃헙 클론한 폴더로 이동
# !mv run.ipynb PyTorch-Deep-Learning-Template/
# !cd PyTorch-Deep-Learning-Template

# %% [markdown]
# **데이터셋 다운로드 하셔서 dataset폴더에 넣으세요. 폴더 안에는 train, val 폴더가 있을꺼에요.**
#
#  - 링크 : https://drive.google.com/open?id=1b2w3QyounBzRdyjmp98D0qXMsZitJUSp

# %% [markdown]
# **---------------------------처음 한 번만 실행 끝!!---------------------------**

# %%
# 패키지 다운로드
# !pip install -r requirements.txt

# %%
# 학습 돌리는 파일 main.py
# !python3 main.py
